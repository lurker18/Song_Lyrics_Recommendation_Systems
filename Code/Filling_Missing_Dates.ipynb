# %%
import pandas as pd

df1 = pd.read_csv('C:\\Users\\Hydra18\\Desktop\\텍스트이해와인공지능\\Project\\Dataset\\Top_5000_Songs_Lyrics_Genres_2010_2021.csv', encoding = 'utf-8')
df2 = pd.read_csv('C:\\Users\\Hydra18\\Desktop\\텍스트이해와인공지능\\Project\\Dataset\\Top_Songs_2010_2021[Filtered].csv', encoding = 'utf-8')
# Out:
#           Dates                            Song  \
# 0    2010-01-02                         Tik Tok
# 1    2010-01-02            Empire State Of Mind
# 2    2010-01-02                     Bad Romance
# 3    2010-01-02                          Replay
# 4    2010-01-02                       Fireflies
# ..          ...                             ...
# 145  2010-02-20   I Made It (Cash Money Heroes)
# 146  2010-02-20  Bridge Over Troubled Water
# 147  2010-02-20                      F**k Today
# 148  2010-02-20                        Who I Am
# 149  2010-02-20                   American Star
#
#                                                 Artist
# 0                                                Kesha
# 1                              Jay-Z Feat. Alicia Keys
# 2                                            Lady Gaga
# 3                                                 Iyaz
# 4                                             Owl City
# ..                                                 ...
# ...

# %%
test = df1.merge(df2, how = 'left', on = ['Song', 'Artist'])

# %%
test.tail(200)
# Out:
#                   Song          Artist  \
# 4947  You're Welcome    Dwayne Johnson
# 4948       Distraction         Kehlani
# 4949   How Far I'll Go    Alessia Cara
# 4950  False Prophets           J. Cole
# 4951  Dirt On My Boots       Jon Pardi
# ...                ...             ...
# 5142      On My Mind    Ellie Goulding
# 5143           Jumpman  Drake & Future
# 5144          Infinity   One Direction
# 5145      RGF Island         Fetty Wap
# 5146  Diamonds Dancing  Drake & Future
#
#                                                  Lyrics        Genre  \
# 4947  Ok, ok, I see what's happening here\nYou're fa...   Soundtrack
# 4948  Do you, do you, do you wanna be\nDo me a favor...     R&B/Soul
# 4949  I've been standing at the edge of the water\n'...   Soundtrack
# 4950  Somebody shoulda told me it would be like this...  Hip-Hop/Rap
# 4951  Been up since the crack of dawn\nJust trying t...      Country
# ...                                                 ...          ...
# ...

# %%
import csv

test.to_csv('C:\\Users\\Hydra18\\Desktop\\텍스트이해와인공지능\\Project\\Dataset\\temp.csv', index = None, encoding = 'UTF-8-sig')

# %%
# Out:
# C:\Users\Hydra18\anaconda3\envs\tensor\lib\site-packages\IPython\core\interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
t
# Out:
#                    Song                   Artist  \
# 0               Tik Tok                    Kesha
# 1  Empire State Of Mind  Jay-Z Feat. Alicia Keys
# 2           Bad Romance                Lady Gaga
# 3                Replay                     Iyaz
# 4             Fireflies                 Owl City
#
#                                               Lyrics        Genre       Dates
# 0  Wake up in the mornin' feeling like P. Diddy (...          Pop  2010-01-02
# 1  Yeah\nYeah, I'm out that Brooklyn, now I'm dow...  Hip-Hop/Rap  2010-01-02
# 2  Oh-oh-oh-oh-oooh\nOh-oh-oh-oh-oooh, oh-oh-oh\n...          Pop  2010-01-02
# 3  Shawty's like a melody in my head\nThat I can'...  Hip-Hop/Rap  2010-01-02
# 4  You would not believe your eyes\nIf ten millio...   Electronic  2010-01-02
